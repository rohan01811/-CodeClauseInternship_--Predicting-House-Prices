# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("customer_churn_data.csv")

# %%
df
# Out:
#      CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0             1   49    Male       4           88.35  Month-to-Month
# 1             2   43    Male       0           36.67  Month-to-Month
# 2             3   51  Female       2           63.79  Month-to-Month
# 3             4   60  Female       8          102.34        One-Year
# 4             5   42    Male      32           69.01  Month-to-Month
# ..          ...  ...     ...     ...             ...             ...
# 995         996   42    Male      41           37.14  Month-to-Month
# 996         997   62    Male       9           80.93  Month-to-Month
# 997         998   51  Female      15          111.72  Month-to-Month
# 998         999   39    Male      68           65.67        One-Year
# 999        1000   50    Male       1           56.67  Month-to-Month
#
#     InternetService  TotalCharges TechSupport Churn
# 0       Fiber Optic        353.40         Yes   Yes
# ...

# %%
df.shape
# Out:
# (1000, 10)

# %%
ty=df.dtypes
ty
# Out:
# CustomerID           int64
# Age                  int64
# Gender              object
# Tenure               int64
# MonthlyCharges     float64
# ContractType        object
# InternetService     object
# TotalCharges       float64
# TechSupport         object
# Churn               object
# dtype: object

# %%
df.isna().sum()
# Out:
# CustomerID           0
# Age                  0
# Gender               0
# Tenure               0
# MonthlyCharges       0
# ContractType         0
# InternetService    297
# TotalCharges         0
# TechSupport          0
# Churn                0
# dtype: int64

# %%
value_count = df['InternetService'].value_counts()
value_count
# Out:
# InternetService
# Fiber Optic    395
# DSL            308
# Name: count, dtype: int64

# %%
df.InternetService.replace('Fiber Optic',1,inplace = True)
df.InternetService.replace('DSL',2,inplace = True)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2176\3032092109.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.InternetService.replace('Fiber Optic',1,inplace = True)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2176\3032092109.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['InternetService'] = df['InternetService'].fillna(0)

# %%
df
# Out:
#      CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0             1   49    Male       4           88.35  Month-to-Month
# 1             2   43    Male       0           36.67  Month-to-Month
# 2             3   51  Female       2           63.79  Month-to-Month
# 3             4   60  Female       8          102.34        One-Year
# 4             5   42    Male      32           69.01  Month-to-Month
# ..          ...  ...     ...     ...             ...             ...
# 995         996   42    Male      41           37.14  Month-to-Month
# 996         997   62    Male       9           80.93  Month-to-Month
# 997         998   51  Female      15          111.72  Month-to-Month
# 998         999   39    Male      68           65.67        One-Year
# 999        1000   50    Male       1           56.67  Month-to-Month
#
#      InternetService  TotalCharges TechSupport Churn
# 0                1.0        353.40         Yes   Yes
# ...

# %%
df.isna().sum()
# Out:
# CustomerID         0
# Age                0
# Gender             0
# Tenure             0
# MonthlyCharges     0
# ContractType       0
# InternetService    0
# TotalCharges       0
# TechSupport        0
# Churn              0
# dtype: int64

# %%
value_count1 = df['ContractType'].value_counts()
value_count1
# Out:
# ContractType
# Month-to-Month    511
# One-Year          289
# Two-Year          200
# Name: count, dtype: int64

# %%
df.ContractType.replace('Month-to-Month',0,inplace = True)
df.ContractType.replace('One-Year',1,inplace = True)
df.ContractType.replace('Two-Year',2,inplace = True)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2176\3159724070.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.ContractType.replace('Month-to-Month',0,inplace = True)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2176\3159724070.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.Gender.replace('Male',1,inplace = True)
df.Gender.replace('Female',0,inplace = True)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2176\1763402946.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Gender.replace('Male',1,inplace = True)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2176\1763402946.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.TechSupport.replace('No',0,inplace = True)
df.TechSupport.replace('Yes',1,inplace = True)
df.Churn.replace('No',0,inplace = True)
df.Churn.replace('Yes',1,inplace = True)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2176\2441235069.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.TechSupport.replace('No',0,inplace = True)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2176\2441235069.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df
# Out:
#      CustomerID  Age  Gender  Tenure  MonthlyCharges  ContractType  \
# 0             1   49       1       4           88.35             0
# 1             2   43       1       0           36.67             0
# 2             3   51       0       2           63.79             0
# 3             4   60       0       8          102.34             1
# 4             5   42       1      32           69.01             0
# ..          ...  ...     ...     ...             ...           ...
# 995         996   42       1      41           37.14             0
# 996         997   62       1       9           80.93             0
# 997         998   51       0      15          111.72             0
# 998         999   39       1      68           65.67             1
# 999        1000   50       1       1           56.67             0
#
#      InternetService  TotalCharges  TechSupport  Churn
# 0                1.0        353.40            1      1
# ...

# %%
churn_counts = df['Churn'].value_counts()
churn_counts
# Out:
# Churn
# 1    883
# 0    117
# Name: count, dtype: int64

# %%
churn_counts.plot(kind='bar', color=['green', 'red'])
plt.title("Churn-TotalCharges COMPARISION")
plt.show()

# %%
sns.scatterplot(data=df, x='Tenure', y='TotalCharges', hue='Churn', style='Churn', palette='Set2', markers={0: 'o', 1: 's'})
# plt.title('GRE Score vs CGPA')
plt.xlabel('Age')
plt.ylabel('TotalCharges')
plt.legend(title='Admitted', loc='upper left')
plt.show()

# %%
df
# Out:
#      CustomerID  Age  Gender  Tenure  MonthlyCharges  ContractType  \
# 0             1   49       1       4           88.35             0
# 1             2   43       1       0           36.67             0
# 2             3   51       0       2           63.79             0
# 3             4   60       0       8          102.34             1
# 4             5   42       1      32           69.01             0
# ..          ...  ...     ...     ...             ...           ...
# 995         996   42       1      41           37.14             0
# 996         997   62       1       9           80.93             0
# 997         998   51       0      15          111.72             0
# 998         999   39       1      68           65.67             1
# 999        1000   50       1       1           56.67             0
#
#      InternetService  TotalCharges  TechSupport  Churn
# 0                1.0        353.40            1      1
# ...

# %%
x=df.iloc[:,[1,2,3,4,5,6,8,9]]
x
# Out:
#      Age  Gender  Tenure  MonthlyCharges  ContractType  InternetService  \
# 0     49       1       4           88.35             0              1.0
# 1     43       1       0           36.67             0              1.0
# 2     51       0       2           63.79             0              1.0
# 3     60       0       8          102.34             1              2.0
# 4     42       1      32           69.01             0              0.0
# ..   ...     ...     ...             ...           ...              ...
# 995   42       1      41           37.14             0              1.0
# 996   62       1       9           80.93             0              0.0
# 997   51       0      15          111.72             0              1.0
# 998   39       1      68           65.67             1              0.0
# 999   50       1       1           56.67             0              0.0
#
#      TechSupport  Churn
# 0              1      1
# 1              1      1
# 2              0      1
# ...

# %%
y=df.iloc[:,[7]]
y
# Out:
#      TotalCharges
# 0          353.40
# 1            0.00
# 2          127.58
# 3          818.72
# 4         2208.32
# ..            ...
# 995       1522.74
# 996        728.37
# 997       1675.80
# 998       4465.56
# 999         56.67
#
# [1000 rows x 1 columns]

# %%
x1_train,x1_test,y1_train,y1_test = tts(x,y,test_size = 0.2)

# %%
from sklearn.model_selection import train_test_split as tts
import sklearn.linear_model as lm
from sklearn.metrics import mean_squared_error 
import math

# %%
model=lm.LinearRegression()

# %%
x1_mul = np.array(x1_train)
y1_mul = np.array(y1_train)
x2_mul = np.array(x1_test)
y2_mul = np.array(y1_test)

# %%
model.fit(x1_mul,y1_mul)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x2_mul)

# %%
meanerr=mean_squared_error(y2_mul,y_pred)
meanerr
# Out:
# np.float64(345274.9735914525)

# %%
squared=math.sqrt(meanerr)
squared
# Out:
# 587.6010326671087

# %%
r2_score=model.score(x2_mul,y2_mul)
r2_score
# Out:
# 0.8924086052958995

# %%
plt.plot(x2_mul,y_pred,color = 'red')
plt.title("Linear regression for multivariate")
# Out:
# Text(0.5, 1.0, 'Linear regression for multivariate')
