# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Housing.csv")

# %%
df.shape
# Out:
# (545, 13)

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
ty=df.dtypes
ty
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.isna().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
plt.bar(df.bedrooms,df.price)
plt.xlabel('No. of Bedrooms')
plt.ylabel('Price')
plt.title("Price-Bedrooms COMPARISION")
plt.show()

# %%
sns.scatterplot(x=df.area,y=df.price)
plt.xlabel("Area")
plt.ylabel('Price')
plt.title("Price-Area COMPARISION")
plt.show()

# %%
from sklearn.model_selection import train_test_split as tts
import  sklearn.linear_model as lm

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
x=df.iloc[:,[1,2]]

# %%
x
# Out:
#      area  bedrooms
# 0    7420         4
# 1    8960         4
# 2    9960         3
# 3    7500         4
# 4    7420         4
# ..    ...       ...
# 540  3000         2
# 541  2400         3
# 542  3620         2
# 543  2910         3
# 544  3850         3
#
# [545 rows x 2 columns]

# %%
y=df["price"]

# %%
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
x_train,x_test,y_train,y_test = tts(x,y,test_size = 0.2)

# %%
x_train
# Out:
#      area  bedrooms
# 408  4000         2
# 100  6600         3
# 70   4000         3
# 227  6000         2
# 16   6600         4
# ..    ...       ...
# 491  2640         2
# 172  8400         3
# 261  3510         3
# 274  6450         4
# 155  6100         3
#
# [436 rows x 2 columns]

# %%
y_train
# Out:
# 408    3430000
# 100    6230000
# 70     6790000
# 227    4690000
# 16     9100000
#         ...
# 491    2835000
# 172    5250000
# 261    4473000
# 274    4340000
# 155    5530000
# Name: price, Length: 436, dtype: int64

# %%
model=lm.LinearRegression()

# %%
x1_mul = np.array(x_train)
y1_mul = np.array(y_train)
x2_mul = np.array(x_test)
y2_mul = np.array(y_test)
np.shape(x1_mul)
# Out:
# (436, 2)

# %%
x1_mul
# Out:
# array([[ 4000,     2],
#        [ 6600,     3],
#        [ 4000,     3],
#        [ 6000,     2],
#        [ 6600,     4],
#        [ 5500,     4],
#        [ 3460,     4],
#        [ 5000,     3],
#        [ 5720,     2],
#        [ 6550,     3],
#        [ 3420,     5],
#        [ 4520,     3],
#        [ 8250,     3],
#        [ 7000,     3],
#        [ 3650,     3],
#        [ 5960,     3],
#        [ 4800,     3],
#        [ 4080,     3],
#        [ 5400,     5],
#        [ 6020,     3],
#        [ 2880,     3],
#        [ 3630,     3],
#        [ 3510,     3],
#        [ 4960,     2],
#        [ 2400,     3],
#        [ 8580,     4],
#        [ 3300,     3],
#        [ 7800,     3],
#        [ 4785,     3],
#        [ 4500,     2],
#        [ 2910,     3],
#        [ 3000,     3],
#        [ 4600,     3],
#        [ 2145,     3],
#        [ 5076,     3],
#        [ 5200,     4],
#        [ 4040,     2],
#        [ 4632,     4],
#        [ 6360,     4],
#        [ 4950,     4],
# ...

# %%
y1_mul
# Out:
# array([ 3430000,  6230000,  6790000,  4690000,  9100000,  3920000,
#         4007500,  6440000,  5075000,  7875000,  1960000,  4900000,
#         4193000,  4200000,  5530000,  3640000,  5866000,  4165000,
#         5565000,  3710000,  2520000,  4025000,  4515000,  3080000,
#         2100000, 10150000,  2835000,  9240000,  3395000,  3080000,
#         1750000,  2485000,  4200000,  4200000,  3010000,  2852500,
#         3710000,  4130000,  7035000,  4382000,  5250000,  6195000,
#         4620000,  3118850,  4480000,  9100000,  3360000,  4515000,
#         2870000,  3675000,  7455000,  4270000,  7980000,  3675000,
#         6020000,  4690000,  3745000,  1890000,  4970000,  2310000,
#         2940000,  3220000,  3780000,  3465000,  5740000,  3115000,
#         5740000,  2940000,  4893000,  4550000,  4550000,  3850000,
#         2870000,  7070000,  2380000,  4060000,  3920000,  5600000,
#         1890000,  5110000,  3332000,  4480000,  3360000,  8120000,
# ...

# %%
x1_mul.shape
# Out:
# (436, 2)

# %%
y1_mul.shape
# Out:
# (436,)

# %%
model.fit(x1_mul,y1_mul)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x2_mul)
y_pred.shape
# Out:
# (109,)

# %%
y_pred
# Out:
# array([3437021.80164098, 5743832.67860492, 5902993.99836046,
#        5134701.98943414, 3947341.61200256, 3475118.92605055,
#        3585418.93011165, 3921943.52906285, 3913477.50141628,
#        5587876.11318136, 4721983.1416638 , 3233837.13812328,
#        6622606.34831899, 5141051.51016907, 3424322.76017112,
#        4429905.18785711, 3627507.42368883, 3807652.15583414,
#        5456169.39534816, 3170341.930774  , 4230953.53816269,
#        4379109.02197768, 8188821.46293462, 4040467.91611484,
#        3610575.36839569, 4783603.48675712, 4648147.04441199,
#        4294448.74551197, 5141051.51016907, 4326196.34918661,
#        5768384.15877998, 4929400.81900479, 4243652.57963254,
#        5367759.39437052, 5069573.56448457, 5293440.00780735,
#        4506099.43667624, 4019302.84699841, 5572818.92014419,
#        3036578.69395817, 3858448.32171356, 4775319.1158372 ,
#        3432788.7878177 , 4280903.10127746, 5211137.88290896,
# ...

# %%
from sklearn.metrics import mean_squared_error

# %%
meanerr2=mean_squared_error(y2_mul,y_pred)

# %%
meanerr2
# Out:
# np.float64(2097533846805.4558)

# %%
import math

# %%
sqr=math.sqrt(meanerr2)
sqr
# Out:
# 1448286.5209638097

# %%
r2_score = model.score(x2_mul,y2_mul)
r2_score
# Out:
# 0.37553350119945283

# %%
y2_pred=model.predict(x1_mul)
y2_pred
# Out:
# array([ 3593643.31310254,  5395032.3395662 ,  4294448.74551197,
#         4440246.07775964,  6095837.77197562,  5630206.25141422,
#         4766671.43146398,  4717750.12784052,  4321721.69070765,
#         5373867.27044977,  5450544.80858026,  4514565.46432281,
#         6093479.6204083 ,  5564352.89249762,  4146293.26169698,
#         5124119.45487593,  4633089.85137481,  4328312.85609825,
#         6288681.54559079,  5149517.53781564,  3820351.197304  ,
#         4137827.23405041,  4087031.06817098,  4000012.64013795,
#         3617166.53378629,  6933974.50898615,  3998137.77788199,
#         5902993.99836046,  4626740.33063988,  3805294.00426682,
#         3833050.23877385,  3871147.36318342,  4548429.5749091 ,
#         3509224.68129251,  4749921.03289749,  5503215.83671565,
#         3610575.36839569,  5262780.65155304,  5994245.44021677,
#         5397390.49113352,  7450402.19542698,  4929400.81900479,
#         5005595.06782393,  3616319.93102163,  5211137.88290896,
# ...

# %%
x1_mul.shape
# Out:
# (436, 2)

# %%
y1_mul.shape
# Out:
# (436,)

# %%
x1 = x_train.iloc[:, 0]  
x2 = x_train.iloc[:, 1]

# %%
plt.figure(figsize=(12, 6))

plt.scatter(x1, y_train, label='Area vs price', color='b')
plt.scatter(x2, y_train, label='bedrooms vs Target', color='r')
plt.plot(x1_mul, y2_pred, label='Predicted line', color='y')
plt.xlabel("Feature Values")
plt.ylabel("Target Values")
plt.title("Scatter Plot of Features vs Target")
plt.legend()
plt.show()
